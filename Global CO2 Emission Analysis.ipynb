# %% [markdown]
# # Analysis of Global Emissions Data
#
# #### In this Notebook I will use CO2 data to visulize historical pollution of CO2 emission. The dataset contains yearly CO2 emission per country from 1850.
#
# #### The structure is as follows:
# - Preparation of the data
# - Analysis of Sweden
# - Analysis of the USA
# - Comparison between Sweden and the USA
# - CO2 Emissions in 2019
# - Global CO2 emission per year
# - Comparison between Sweden and China

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('co2-data.csv')

df.head()
# Out:
#   iso_code      country  year    co2  consumption_co2  co2_growth_prct  \
# 0      AFG  Afghanistan  1949  0.015              NaN              NaN
# 1      AFG  Afghanistan  1950  0.084              NaN            475.0
# 2      AFG  Afghanistan  1951  0.092              NaN              8.7
# 3      AFG  Afghanistan  1952  0.092              NaN              0.0
# 4      AFG  Afghanistan  1953  0.106              NaN             16.0
#
#    co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  ...  \
# 0             NaN        NaN           0.002                         NaN  ...
# 1           0.070        NaN           0.011                         NaN  ...
# 2           0.007        NaN           0.012                         NaN  ...
# 3           0.000        NaN           0.012                         NaN  ...
# 4           0.015        NaN           0.013                         NaN  ...
#
#    ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# ...

# %% [markdown]
# ### Analysis of Sweden

# %%
df_swe = df[df['country']=='Sweden']

df_swe.tail()
# Out:
#       iso_code country  year     co2  consumption_co2  co2_growth_prct  \
# 21207      SWE  Sweden  2015  43.337           70.362             0.00
# 21208      SWE  Sweden  2016  42.973           69.439            -0.84
# 21209      SWE  Sweden  2017  42.307           70.159            -1.55
# 21210      SWE  Sweden  2018  41.766           70.781            -1.28
# 21211      SWE  Sweden  2019  42.767              NaN             2.40
#
#        co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  \
# 21207          -0.001     27.025           4.438                       7.206
# 21208          -0.364     26.466           4.369                       7.060
# 21209          -0.666     27.853           4.271                       7.083
# 21210          -0.541     29.014           4.188                       7.098
# 21211           1.000        NaN           4.261                         NaN
#
#        ...  ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# ...

# %%
df_swe.set_index('year')
# Out:
#      iso_code country     co2  consumption_co2  co2_growth_prct  \
# year
# 1834      SWE  Sweden   0.033              NaN              NaN
# 1835      SWE  Sweden     NaN              NaN             0.00
# 1836      SWE  Sweden     NaN              NaN             0.00
# 1837      SWE  Sweden     NaN              NaN             0.00
# 1838      SWE  Sweden     NaN              NaN             0.00
# ...       ...     ...     ...              ...              ...
# 2015      SWE  Sweden  43.337           70.362             0.00
# 2016      SWE  Sweden  42.973           69.439            -0.84
# 2017      SWE  Sweden  42.307           70.159            -1.55
# 2018      SWE  Sweden  41.766           70.781            -1.28
# 2019      SWE  Sweden  42.767              NaN             2.40
#
#       co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  \
# year
# 1834             NaN        NaN           0.011                         NaN
# ...

# %%
# drop rows before 1950
df_swe = df_swe[df_swe.year > 1949]

# %%
plt.figure(figsize=(12,6))
plt.title('Historical CO2 Emission per capita in Sweden')
plt.plot(df_swe['year'], df_swe['co2_per_capita'], color='blue', label = 'Sweden')
plt.legend()
plt.show()

# %%
df_swe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70 entries, 21142 to 21211
# Data columns (total 58 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   iso_code                             70 non-null     object
#  1   country                              70 non-null     object
#  2   year                                 70 non-null     int64
#  3   co2                                  70 non-null     float64
#  4   consumption_co2                      29 non-null     float64
#  5   co2_growth_prct                      70 non-null     float64
#  6   co2_growth_abs                       70 non-null     float64
#  7   trade_co2                            29 non-null     float64
#  8   co2_per_capita                       70 non-null     float64
#  9   consumption_co2_per_capita           29 non-null     float64
#  10  share_global_co2                     70 non-null     float64
# ...

# %%
plt.figure(figsize=(16,6))
plt.title('Historical CO2 Emission per capita in Sweden')
plt.plot(df_swe['year'], df_swe['oil_co2'], color='blue', label = 'Oil')
plt.plot(df_swe['year'], df_swe['gas_co2'], color='green', label = 'Gas')
plt.plot(df_swe['year'], df_swe['coal_co2'], color='red', label = 'Coal')
plt.plot(df_swe['year'], df_swe['flaring_co2'], color='orange', label = 'Flaring')
plt.plot(df_swe['year'], df_swe['cement_co2'], color='purple', label = 'Cement')
plt.legend()
plt.show()

# %% [markdown]
# ### Analysis of United States of America

# %%
df_us = df[df['iso_code']=='USA']

df_us.head()
# Out:
#       iso_code        country  year    co2  consumption_co2  co2_growth_prct  \
# 23305      USA  United States  1800  0.253              NaN              NaN
# 23306      USA  United States  1801  0.267              NaN             5.80
# 23307      USA  United States  1802  0.289              NaN             8.22
# 23308      USA  United States  1803  0.297              NaN             2.53
# 23309      USA  United States  1804  0.333              NaN            12.35
#
#        co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  \
# 23305             NaN        NaN           0.042                         NaN
# 23306           0.015        NaN           0.044                         NaN
# 23307           0.022        NaN           0.046                         NaN
# 23308           0.007        NaN           0.047                         NaN
# 23309           0.037        NaN           0.052                         NaN
#
# ...

# %%
# drop rows before 1950
df_us = df_us[df_us.year > 1949]
df_us.head()
# Out:
#       iso_code        country  year       co2  consumption_co2  \
# 23455      USA  United States  1950  2536.096              NaN
# 23456      USA  United States  1951  2612.719              NaN
# 23457      USA  United States  1952  2545.380              NaN
# 23458      USA  United States  1953  2606.057              NaN
# 23459      USA  United States  1954  2483.296              NaN
#
#        co2_growth_prct  co2_growth_abs  trade_co2  co2_per_capita  \
# 23455            17.39         375.716        NaN          15.970
# 23456             3.02          76.624        NaN          16.241
# 23457            -2.58         -67.340        NaN          15.590
# 23458             2.38          60.677        NaN          15.708
# 23459            -4.71        -122.761        NaN          14.717
#
#        consumption_co2_per_capita  ...  ghg_per_capita  methane  \
# 23455                         NaN  ...             NaN      NaN
# ...

# %% [markdown]
# ### Comparison between Sweden and US

# %%
fig, swe_us = plt.subplots(figsize=(16,6))

# %%
swe_us.plot(df_swe['year'], df_swe['co2_per_capita'], color='blue', label='Sweden')
swe_us.plot(df_us['year'], df_us['co2_per_capita'], color='red', label='USA')
swe_us.set_xlabel('Year')
swe_us.set_ylabel('metric tons CO2 per capita')
swe_us.set_title('Historical CO2 Emission per capita: Sweden and US')
swe_us.legend()

fig

# %%
plot_objects = plt.subplots(nrows=1, ncols=2, figsize=(16,6))

fig, (swe_us1, swe_us2)= plot_objects

swe_us1.plot(df_swe['year'], df_swe['co2_per_capita'], color='blue', label='Sweden')
swe_us1.plot(df_us['year'], df_us['co2_per_capita'], color='red', label='USA')
swe_us1.set_xlabel('Year')
swe_us1.set_ylabel('metric tons CO2')
swe_us1.set_title('Historical CO2 Emission per capita: Sweden and US')
swe_us1.legend()

swe_us2.plot(df_swe['year'], df_swe['co2_per_gdp'], color='blue', label='Sweden')
swe_us2.plot(df_us['year'], df_us['co2_per_gdp'], color='red', label='USA')
swe_us2.set_xlabel('Year')
swe_us2.set_ylabel('metric tons CO2')
swe_us2.set_title('Historical CO2 Emission per GDP: Sweden and US')
swe_us2.legend()

# %% [markdown]
# ### Amount of CO2 Emissions in 2019

# %%
df_2019 = df[df['year']==2019]
df_2019.head()
# Out:
#     iso_code      country  year       co2  consumption_co2  co2_growth_prct  \
# 70       AFG  Afghanistan  2019    10.720              NaN             2.56
# 206      NaN       Africa  2019  1448.793              NaN             1.62
# 293      ALB      Albania  2019     5.579              NaN             3.26
# 397      DZA      Algeria  2019   171.707              NaN             4.50
# 427      AND      Andorra  2019     0.470              NaN             1.35
#
#      co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  \
# 70            0.268        NaN           0.282                         NaN
# 206          23.059        NaN           1.109                         NaN
# 293           0.176        NaN           1.936                         NaN
# 397           7.398        NaN           3.988                         NaN
# 427           0.006        NaN           6.099                         NaN
#
# ...

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238 entries, 70 to 24650
# Data columns (total 58 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   iso_code                             215 non-null    object
#  1   country                              238 non-null    object
#  2   year                                 238 non-null    int64
#  3   co2                                  228 non-null    float64
#  4   consumption_co2                      1 non-null      float64
#  5   co2_growth_prct                      238 non-null    float64
#  6   co2_growth_abs                       228 non-null    float64
#  7   trade_co2                            1 non-null      float64
#  8   co2_per_capita                       224 non-null    float64
#  9   consumption_co2_per_capita           1 non-null      float64
#  10  share_global_co2                     228 non-null    float64
# ...

# %% [markdown]
# ##### The upcoming section is only including Emission during 2019 for the five main continents

# %%
#Filtering continents on ISO code with value NaN
df_cont = df_2019[df_2019["iso_code"].isnull()]
df_cont.head(100
            )
# Out:
#       iso_code                     country  year        co2  consumption_co2  \
# 206        NaN                      Africa  2019   1448.793              NaN
# 1230       NaN                        Asia  2019  20241.964              NaN
# 1420       NaN  Asia (excl. China & India)  2019   7450.834              NaN
# 6387       NaN                       EU-27  2019   2916.906              NaN
# 6657       NaN                       EU-28  2019   3286.785              NaN
# 7699       NaN                      Europe  2019   5448.709              NaN
# 7969       NaN        Europe (excl. EU-27)  2019   2540.065              NaN
# 8160       NaN        Europe (excl. EU-28)  2019   2170.186              NaN
# 8748       NaN    French Equatorial Africa  2019        NaN              NaN
# 8884       NaN          French West Africa  2019        NaN              NaN
# 10936      NaN     International transport  2019   1267.690              NaN
# ...

# %%
#Only looking at the five main continents
continents = df_cont.loc[(df_cont['country']== 'Europe') | (df_cont['country']== 'Asia') | (df_cont['country']== 'North America')
           | (df_cont['country']== 'Oceania') | (df_cont['country']== 'South America')]
continents
# Out:
#       iso_code        country  year        co2  consumption_co2  \
# 1230       NaN           Asia  2019  20241.964              NaN
# 7699       NaN         Europe  2019   5448.709              NaN
# 16037      NaN  North America  2019   6481.175              NaN
# 16873      NaN        Oceania  2019    467.762              NaN
# 20377      NaN  South America  2019   1085.107              NaN
#
#        co2_growth_prct  co2_growth_abs  trade_co2  co2_per_capita  \
# 1230              1.63         324.750        NaN           4.400
# 7699             -2.74        -153.264        NaN           7.284
# 16037            -2.39        -158.379        NaN          11.106
# 16873            -0.56          -2.653        NaN          11.212
# 20377            -1.08         -11.849        NaN           2.542
#
#        consumption_co2_per_capita  ...  ghg_per_capita  methane  \
# 1230                          NaN  ...             NaN      NaN
# ...

# %%
continents = continents.dropna(axis='columns')
continents
# Out:
#              country  year        co2  co2_growth_prct  co2_growth_abs  \
# 1230            Asia  2019  20241.964             1.63         324.750
# 7699          Europe  2019   5448.709            -2.74        -153.264
# 16037  North America  2019   6481.175            -2.39        -158.379
# 16873        Oceania  2019    467.762            -0.56          -2.653
# 20377  South America  2019   1085.107            -1.08         -11.849
#
#        co2_per_capita  share_global_co2  cumulative_co2  \
# 1230            4.400             55.55      507517.983
# 7699            7.284             14.95      525126.676
# 16037          11.106             17.79      470217.777
# 16873          11.212              1.28       20474.940
# 20377           2.542              2.98       41637.664
#
#        share_global_cumulative_co2  co2_per_unit_energy  ...  \
# 1230                         30.70                0.245  ...
# 7699                         31.77                0.185  ...
# ...

# %%
plot_objects1 = plt.subplots(nrows=2, ncols=2, figsize=(16,12))

fig, ((cont_tot, cont_change), (co_sh, cont_abs)) = plot_objects1

barWidth = 0.5

cont_tot.bar(continents['country'], continents['co2_per_capita'], width=barWidth, color='#66CDAA')
cont_tot.set_title('CO2 Emissions per capita per continent 2019')

cont_change.bar(continents['country'], continents['co2_growth_prct'], width=barWidth, color='#458B74')
cont_change.set_title('CO2 growth in percent 2019')

co_sh.bar(continents['country'], continents['share_global_cumulative_cement_co2'], width=barWidth, color='#FF6347', label='Centiment')
co_sh.bar(continents['country'], continents['share_global_cumulative_coal_co2'], width=barWidth, color='#8B3626', bottom=continents['share_global_cumulative_cement_co2'], label='Coal')
co_sh.bar(continents['country'], continents['share_global_cumulative_flaring_co2'], width=barWidth, color='#FF8247', bottom=continents['share_global_cumulative_coal_co2'], label='Flaring')
co_sh.bar(continents['country'], continents['share_global_cumulative_gas_co2'], width=barWidth, color='#E3A869', bottom=continents['share_global_cumulative_flaring_co2'], label='Gas')
co_sh.bar(continents['country'], continents['share_global_cumulative_oil_co2'], width=barWidth, color='#CD8162', bottom=continents['share_global_cumulative_gas_co2'], label='Oil')
co_sh.set_title('CO2 Share Global Cumulative')
co_sh.legend()

cont_abs.bar(continents['country'], continents['co2_growth_abs'], width=barWidth, color='#96CDCD')
cont_abs.set_title('CO2 growth in absolute numbers')

plot_objects1
# Out:
# (<Figure size 1152x864 with 4 Axes>,
#  array([[<AxesSubplot:title={'center':'CO2 Emissions per capita per continent 2019'}>,
#          <AxesSubplot:title={'center':'CO2 growth in percent 2019'}>],
#         [<AxesSubplot:title={'center':'CO2 Share Global Cumulative'}>,
#          <AxesSubplot:title={'center':'CO2 growth in absolute numbers'}>]],
#        dtype=object))

# %% [markdown]
# The graphs above shows information about the total CO2 emission, the change in CO2 emission (both in percent and in absolute numbers) and the source of emissions during 2019. In 2019, the Asia has the second lowest CO2 per capita. While other continents are decreasing the CO2 Emissions, the Emssions in Asia is increasing significally. The absolute increase for Asia is larger than the sum of the absoulte decrease of the other continents, which means that the global amount of CO2 emissions increased in 2019.

# %% [markdown]
# ### Global CO2 Emission per year

# %%
df.head()
# Out:
#   iso_code      country  year    co2  consumption_co2  co2_growth_prct  \
# 0      AFG  Afghanistan  1949  0.015              NaN              NaN
# 1      AFG  Afghanistan  1950  0.084              NaN            475.0
# 2      AFG  Afghanistan  1951  0.092              NaN              8.7
# 3      AFG  Afghanistan  1952  0.092              NaN              0.0
# 4      AFG  Afghanistan  1953  0.106              NaN             16.0
#
#    co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  ...  \
# 0             NaN        NaN           0.002                         NaN  ...
# 1           0.070        NaN           0.011                         NaN  ...
# 2           0.007        NaN           0.012                         NaN  ...
# 3           0.000        NaN           0.012                         NaN  ...
# 4           0.015        NaN           0.013                         NaN  ...
#
#    ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# ...

# %%
#Only looking at years after 1950
df_group = df[df.year > 1949]

df_group.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15623 entries, 1 to 24650
# Data columns (total 58 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   iso_code                             14133 non-null  object
#  1   country                              15623 non-null  object
#  2   year                                 15623 non-null  int64
#  3   co2                                  15072 non-null  float64
#  4   consumption_co2                      3815 non-null   float64
#  5   co2_growth_prct                      15480 non-null  float64
#  6   co2_growth_abs                       14949 non-null  float64
#  7   trade_co2                            3815 non-null   float64
#  8   co2_per_capita                       14808 non-null  float64
#  9   consumption_co2_per_capita           3815 non-null   float64
#  10  share_global_co2                     15072 non-null  float64
# ...

# %%
#Only including countries
df_group = df_group[df_group['iso_code'].notna()]

df_group.head()
# Out:
#   iso_code      country  year    co2  consumption_co2  co2_growth_prct  \
# 1      AFG  Afghanistan  1950  0.084              NaN            475.0
# 2      AFG  Afghanistan  1951  0.092              NaN              8.7
# 3      AFG  Afghanistan  1952  0.092              NaN              0.0
# 4      AFG  Afghanistan  1953  0.106              NaN             16.0
# 5      AFG  Afghanistan  1954  0.106              NaN              0.0
#
#    co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  ...  \
# 1           0.070        NaN           0.011                         NaN  ...
# 2           0.007        NaN           0.012                         NaN  ...
# 3           0.000        NaN           0.012                         NaN  ...
# 4           0.015        NaN           0.013                         NaN  ...
# 5           0.000        NaN           0.013                         NaN  ...
#
#    ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# ...

# %%
df_group['year'].unique()
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019], dtype=int64)

# %%
#Creating a pivot table with index year, column CO2 and the sum of the CO2 emission
df_piv = df_group.pivot_table(index='year', values='co2', aggfunc='sum', margins=False)
df_piv
# Out:
#             co2
# year
# 1950  11866.631
# 1951  12593.191
# 1952  12763.031
# 1953  13119.997
# 1954  13405.466
# ...         ...
# 2015  69250.622
# 2016  69252.784
# 2017  70141.785
# 2018  71569.334
# 2019  71612.831
#
# [70 rows x 1 columns]

# %%
df_piv_gdp = df_group.pivot_table(index='year', values='gdp', aggfunc='sum', margins=False)
df_piv_gdp
# Out:
#                gdp
# year
# 1950  1.585967e+13
# 1951  7.992201e+12
# 1952  8.401431e+12
# 1953  8.884521e+12
# 1954  9.099744e+12
# ...            ...
# 2015  1.056939e+14
# 2016  2.147076e+14
# 2017  2.211738e+14
# 2018  2.276454e+14
# 2019  0.000000e+00
#
# [70 rows x 1 columns]

# %%
plt.figure(figsize=(16,6))


plt.subplot(1,2,1)
plt.title('Total Global Historical Co2 Emission ')
plt.plot(df_piv, ':g')

plt.subplot(1,2,2)
plt.title('Total Global Historical GDP')
plt.plot(df_piv_gdp, ':b')

# %% [markdown]
# The first graph shows the Total Global Historical CO2 Emission. The second graph shows the total global historical GDP and we clearly see that there is an seasonal error in the data. The next section will take a closer look at what is causing the error.

# %%
df1 = df_group[['country', 'year', 'gdp']]

# %%
df1[(df1['year']==2000) | (df1['year']==2019)]
# Out:
#            country  year           gdp
# 51     Afghanistan  2000  1.128379e+10
# 70     Afghanistan  2019           NaN
# 274        Albania  2000  1.521426e+10
# 293        Albania  2019           NaN
# 378        Algeria  2000  2.085542e+11
# ...            ...   ...           ...
# 24463        Yemen  2019           NaN
# 24514       Zambia  2000  1.496412e+10
# 24533       Zambia  2019           NaN
# 24631     Zimbabwe  2000  2.676498e+10
# 24650     Zimbabwe  2019           NaN
#
# [428 rows x 3 columns]

# %% [markdown]
# The table shows that many countries does not have a value on years that are not 1980,1990, 2000, 2010. This is the reason to the peaks in the graph.

# %% [markdown]
# ### Comparison between the emission in China and Sweden

# %%
df_group[(df_group['country']=='Sweden') | (df_group['country']=='Germany') | (df_group['country']=='China') | (df_group['country']=='India')]
# Out:
#       iso_code country  year      co2  consumption_co2  co2_growth_prct  \
# 4609       CHN   China  1950   78.582              NaN            32.58
# 4610       CHN   China  1951  101.617              NaN            29.31
# 4611       CHN   China  1952  127.987              NaN            25.95
# 4612       CHN   China  1953  133.784              NaN             4.53
# 4613       CHN   China  1954  160.878              NaN            20.25
# ...        ...     ...   ...      ...              ...              ...
# 21207      SWE  Sweden  2015   43.337           70.362             0.00
# 21208      SWE  Sweden  2016   42.973           69.439            -0.84
# 21209      SWE  Sweden  2017   42.307           70.159            -1.55
# 21210      SWE  Sweden  2018   41.766           70.781            -1.28
# 21211      SWE  Sweden  2019   42.767              NaN             2.40
#
#        co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  \
# ...

# %%
df_swe1 = df_group[df_group['country']=='Sweden']
df_china = df_group[df_group['country']=='China']

# %%
df_swe1 = df_swe1[['country', 'year', 'co2_per_capita', 'consumption_co2_per_capita']]
df_china = df_china[['country', 'year', 'co2_per_capita', 'consumption_co2_per_capita']]

# %%
fig2, comp = plt.subplots(figsize=(14,6))

# %%
comp.plot(df_swe1['year'], df_swe1['co2_per_capita'], 'b')
comp.plot(df_swe1['year'], df_swe1['consumption_co2_per_capita'], 'b--')
comp.plot(df_china['year'], df_china['co2_per_capita'], 'g')
comp.plot(df_china['year'], df_china['consumption_co2_per_capita'], 'g--')

comp.set_xlabel('Year')
comp.set_ylabel('t ton CO2')

comp.set_title('Comparison between Sweden and China')

comp.legend(['Swe, co2 per capita', 'Swe, consumed co2 per capita', 'China, co2 per capita', 'China, consumed co2 per capita'])

fig2

# %% [markdown]
# The graph shows the historical emission of CO2 data in Sweden and China, both actual CO2 emission and the consumed CO2 per capita. The blue lines shows that Sweden has for many years emitted a large amount of CO2 emissions per capita, much more than China. China shows an increasing trend, while the trend in Sweden in decreasing since 1970s. The breaking point between Sweden and Chinas emission per capita happened around 2008. The breaking point in CO2 consumed per capita, has not yet happened.
#
# The next graph will show the absolute total amount of CO2 emission that the both countries has emitted since 1950, per capita. Let's also add USA to this comparison.

# %%
#Sweden
swe_co2 = df_swe1['co2_per_capita'].sum().round()
swe_cons = df_swe1['consumption_co2_per_capita'].sum().round()
print(swe_co2)
print(swe_cons)
# Out:
# 482.0
# 261.0

# %%
#China
chi_co2 = df_china['co2_per_capita'].sum().round()
chi_cons = df_china['consumption_co2_per_capita'].sum().round()
print(chi_co2)
print(chi_cons)
# Out:
# 174.0
# 109.0

# %%
#USA
us_co2 = df_us['co2_per_capita'].sum().round()
us_cons = df_us['consumption_co2_per_capita'].sum().round()
print(us_co2)
print(us_cons)
# Out:
# 1308.0
# 584.0

# %%
plt.figure(figsize=(15,8))

plt.subplot(1,2,1)
plt.title('Sum of total CO2 Emission per capita and year since 1950 ')
plt.bar('Sweden', swe_co2, width=0.5, align='center', color='b')
plt.bar('China', chi_co2, width=0.5, align='center', color='g')
plt.bar('USA', us_co2, width=0.5, align='center', color='r')

plt.subplot(1,2,2)
plt.title('Sum of total consumed CO2 Emission per capita and year since 1990')
plt.bar('Sweden', swe_cons, width=0.5, align='center', color='b')
plt.bar('China', chi_cons, width=0.5, align='center', color='g')
plt.bar('USA', us_cons, width=0.5, align='center', color='r')
# Out:
# <BarContainer object of 1 artists>

# %% [markdown]
# The graph clearly shows big differences in aggregated CO2 per capita between the three countries.
